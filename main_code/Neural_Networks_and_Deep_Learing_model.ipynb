# %%
# Import dependencies
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
# Read CSV file
df = pd.read_csv("exoplanet_data.csv")

# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Select features (columns)

# %%
selected_features = df

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# Assign x and y values
X = df.drop("koi_disposition", axis=1)
y = df["koi_disposition"]

print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# Import Dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Split data in training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Pre-processing
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale the data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train Model - Neural Network
# Use `Neural Network` model

# %%
from tensorflow.keras.utils import to_categorical

# %%
# Step 1: Label encoder
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# %%
# Step 2: Convert encoded labels to one-hot-encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
print(label_encoder.classes_)
# Out:
# ['CANDIDATE' 'CONFIRMED' 'FALSE POSITIVE']

# %%
label_encoder.fit(y)
encoded_y = label_encoder.transform(y)
# pd.plotting.scatter_matrix(X, c=encoded_y, figsize=(40,40));

# %%
# First, create a normal neural network
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=15, activation='relu', input_dim=40))
model.add(Dense(units=3, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 15)                615
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 48
# ...
# Total params: 663
# Trainable params: 663
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Fit the model to the training data
model.fit(X_train_scaled, y_train_categorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Train on 5243 samples
# Epoch 1/100
# 5243/5243 - 1s - loss: 0.9164 - accuracy: 0.5010
# Epoch 2/100
# 5243/5243 - 0s - loss: 0.6858 - accuracy: 0.6845
# Epoch 3/100
# 5243/5243 - 0s - loss: 0.5154 - accuracy: 0.8037
# Epoch 4/100
# 5243/5243 - 0s - loss: 0.4396 - accuracy: 0.8186
# Epoch 5/100
# 5243/5243 - 0s - loss: 0.4036 - accuracy: 0.8240
# Epoch 6/100
# 5243/5243 - 0s - loss: 0.3842 - accuracy: 0.8224
# Epoch 7/100
# 5243/5243 - 0s - loss: 0.3702 - accuracy: 0.8306
# Epoch 8/100
# 5243/5243 - 0s - loss: 0.3609 - accuracy: 0.8274
# Epoch 9/100
# 5243/5243 - 0s - loss: 0.3545 - accuracy: 0.8297
# Epoch 10/100
# 5243/5243 - 0s - loss: 0.3490 - accuracy: 0.8314
# Epoch 11/100
# 5243/5243 - 0s - loss: 0.3434 - accuracy: 0.8383
# Epoch 12/100
# 5243/5243 - 0s - loss: 0.3404 - accuracy: 0.8423
# Epoch 13/100
# 5243/5243 - 0s - loss: 0.3365 - accuracy: 0.8362
# Epoch 14/100
# 5243/5243 - 0s - loss: 0.3326 - accuracy: 0.8407
# Epoch 15/100
# ...

# %% [markdown]
# # Deep Learning

# %%
deep_model = Sequential()
deep_model.add(Dense(units=15, activation='relu', input_dim=40))
deep_model.add(Dense(units=15, activation='relu'))
deep_model.add(Dense(units=3, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 15)                615
# _________________________________________________________________
# dense_3 (Dense)              (None, 15)                240
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 48
# ...
# Total params: 903
# Trainable params: 903
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

deep_model.fit(X_train_scaled, y_train_categorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Train on 5243 samples
# Epoch 1/100
# 5243/5243 - 1s - loss: 0.9832 - accuracy: 0.4764
# Epoch 2/100
# 5243/5243 - 0s - loss: 0.6405 - accuracy: 0.7229
# Epoch 3/100
# 5243/5243 - 0s - loss: 0.4167 - accuracy: 0.8060
# Epoch 4/100
# 5243/5243 - 0s - loss: 0.3730 - accuracy: 0.8150
# Epoch 5/100
# 5243/5243 - 0s - loss: 0.3588 - accuracy: 0.8245
# Epoch 6/100
# 5243/5243 - 0s - loss: 0.3515 - accuracy: 0.8226
# Epoch 7/100
# 5243/5243 - 0s - loss: 0.3446 - accuracy: 0.8341
# Epoch 8/100
# 5243/5243 - 0s - loss: 0.3405 - accuracy: 0.8306
# Epoch 9/100
# 5243/5243 - 0s - loss: 0.3369 - accuracy: 0.8365
# Epoch 10/100
# 5243/5243 - 0s - loss: 0.3322 - accuracy: 0.8392
# Epoch 11/100
# 5243/5243 - 0s - loss: 0.3285 - accuracy: 0.8432
# Epoch 12/100
# 5243/5243 - 0s - loss: 0.3268 - accuracy: 0.8396
# Epoch 13/100
# 5243/5243 - 0s - loss: 0.3236 - accuracy: 0.8428
# Epoch 14/100
# 5243/5243 - 0s - loss: 0.3224 - accuracy: 0.8436
# Epoch 15/100
# ...

# %% [markdown]
# # Compare the two models (Neural Networks and Deep Learning)

# %%
# Neural Networks
model_loss, model_accuracy = model.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f'Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 1748/1 - 0s - loss: 0.4086 - accuracy: 0.8719
# Normal Neural Network - Loss: 0.294247181382823, Accuracy: 0.8718535304069519

# %%
# Deep Learning
model_loss, model_accuracy = deep_model.evaluate(X_test_scaled, y_test_categorical, verbose=2)
print(f'Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 1748/1 - 0s - loss: 0.3666 - accuracy: 0.8896
# Deep Neural Network - Loss: 0.27587784482357974, Accuracy: 0.8895881175994873

# %% [markdown]
# # Save the Model

# %%
# Saving neural model
model.save('efmercado_normal_neural.h5')

# Saving deep model
deep_model.save('efmercado_deep_learning.h5')
